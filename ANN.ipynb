# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa
import librosa.display

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score

import tensorflow as tf
from tensorflow.keras import layers, models
from keras.utils import to_categorical
import itertools

from sklearn.preprocessing import StandardScaler

import warnings
warnings.simplefilter('ignore')
# Out:
# D:\Anaconda3\envs\speech5p310\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
def convert_to_mel_spectrogram(file_path):
  y, sr = librosa.load(file_path, sr=None)


  mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)


  mel_spectrogram_db = librosa.power_to_db(mel_spectrogram, ref=np.max)
  return mel_spectrogram_db, sr

def plotting_mel_spectogram(spectrogram, sr):
  plt.figure(figsize=(10, 4))
  librosa.display.specshow(spectrogram, sr=sr, x_axis='time', y_axis='mel')
  plt.colorbar(format='%+2.0f dB')
  plt.title('Mel Spectrogram')
  plt.tight_layout()
  plt.show()

def get_spectrogram_plot(file_path):
  spectrogram, sr = convert_to_mel_spectrogram(file_path)
  plotting_mel_spectogram(spectrogram, sr)

# %%
import os
import librosa

directory_path = './wavfiles/'
files = os.listdir(directory_path)

for file in files:

    if file.endswith('.wav'):
        get_spectrogram_plot(f"./wavfiles/{file}")
        break

def get_spectrogram_plot(file_path):
    spectrogram, sr = convert_to_mel_spectrogram(file_path)
    plotting_mel_spectogram(spectrogram, sr)

def convert_to_mel_spectrogram(file_path):
    y, sr = librosa.load(file_path, sr=None)
 
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
    return mel_spectrogram, sr

def plotting_mel_spectogram(spectrogram, sr):
    pass

# %%
metadata = pd.read_csv("./bird_songs_metadata.csv")

# %%
metadata.shape
# Out:
# (5422, 18)

# %%
metadata.head(10)
# Out:
#        id       genus   species subspecies           name  \
# 0  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 1  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 2  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 3  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 4  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 5  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 6  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 7  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 8  557838  Thryomanes  bewickii        NaN  Bewick's Wren
# 9  557838  Thryomanes  bewickii        NaN  Bewick's Wren
#
#                 recordist        country  \
# 0  Whitney Neufeld-Kaiser  United States
# 1  Whitney Neufeld-Kaiser  United States
# 2  Whitney Neufeld-Kaiser  United States
# 3  Whitney Neufeld-Kaiser  United States
# 4  Whitney Neufeld-Kaiser  United States
# 5  Whitney Neufeld-Kaiser  United States
# 6  Whitney Neufeld-Kaiser  United States
# 7  Whitney Neufeld-Kaiser  United States
# 8  Whitney Neufeld-Kaiser  United States
# 9  Whitney Neufeld-Kaiser  United States
#
#                                   location  latitude  longitude altitude  \
# 0  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 1  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 2  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 3  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 4  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 5  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 6  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 7  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 8  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
# 9  Arlington, Snohomish County, Washington   48.0708  -122.1006      100
#
#                    sound_type                   source_url  \
# 0  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 1  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 2  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 3  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 4  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 5  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 6  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 7  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 8  adult, sex uncertain, song  //www.xeno-canto.org/557838
# 9  adult, sex uncertain, song  //www.xeno-canto.org/557838
#
#                                         license   time        date  \
# 0  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 1  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 2  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 3  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 4  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 5  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 6  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 7  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 8  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
# 9  //creativecommons.org/licenses/by-nc-sa/4.0/  11:51  2020-03-14
#
#                                              remarks       filename
# 0  Recorded with Voice Record Pro on iPhone7, nor...   557838-0.wav
# 1  Recorded with Voice Record Pro on iPhone7, nor...   557838-1.wav
# 2  Recorded with Voice Record Pro on iPhone7, nor...   557838-4.wav
# 3  Recorded with Voice Record Pro on iPhone7, nor...   557838-5.wav
# 4  Recorded with Voice Record Pro on iPhone7, nor...   557838-6.wav
# 5  Recorded with Voice Record Pro on iPhone7, nor...   557838-8.wav
# 6  Recorded with Voice Record Pro on iPhone7, nor...   557838-9.wav
# 7  Recorded with Voice Record Pro on iPhone7, nor...  557838-11.wav
# 8  Recorded with Voice Record Pro on iPhone7, nor...  557838-14.wav
# 9  Recorded with Voice Record Pro on iPhone7, nor...  557838-15.wav

# %%
librosa_audio_data, librosa_sample_rate = librosa.load('./wavfiles/11713-1.wav')
print(librosa_audio_data)
print(librosa_sample_rate)
# Out:
# [ 0.15442057 -0.2753804  -0.5479337  ...  0.06947865  0.03835445
#  -0.06795005]
# 22050

# %%
librosa_audio_data.shape
# Out:
# (66150,)

# %%
plt.figure(figsize=(10,4))
plt.plot(librosa_audio_data)

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio_data, sr=librosa_sample_rate, n_mfcc = 39)
mfccs.shape
# Out:
# (39, 130)

# %%
def get_mfcc_features(file_path):
  y, sr = librosa.load(file_path)
  mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=39)
  scaled_features = np.mean(mfccs.T, axis=0)
  return scaled_features

# %%
from tqdm import tqdm

features_and_labels = []
for index, row in tqdm(metadata.iterrows(), total=metadata.shape[0]):
    file_name = "./wavfiles/" + row['filename']
    labels = row['name']
    scaled_features_each = get_mfcc_features(file_name)
    features_and_labels.append([scaled_features_each, labels])
# Out:
# 100%|██████████| 5422/5422 [01:00<00:00, 89.76it/s]

# %%
features_and_labels_df = pd.DataFrame(features_and_labels, columns=['features', 'labels'])
features_and_labels_df
# Out:
#                                                features             labels
# 0     [-132.85225, 81.1399, 17.018225, 54.974297, -1...      Bewick's Wren
# 1     [-147.74393, 99.42544, 20.885643, 44.11881, 1....      Bewick's Wren
# 2     [-92.42778, 84.10635, 17.362778, 53.86046, -8....      Bewick's Wren
# 3     [-93.07557, 81.17431, 16.225544, 52.08842, -8....      Bewick's Wren
# 4     [-107.95914, 92.416, 17.773256, 43.13245, -1.8...      Bewick's Wren
# ...                                                 ...                ...
# 5417  [-265.4909, 25.234486, -71.860214, 21.496227, ...  Northern Cardinal
# 5418  [-229.15498, 6.058426, -86.364815, 31.295118, ...  Northern Cardinal
# 5419  [-228.50348, 9.504912, -82.23682, 27.831066, 7...  Northern Cardinal
# 5420  [-222.64116, 13.23448, -77.96408, 26.501926, 1...  Northern Cardinal
# 5421  [-256.7084, 39.117977, -70.26597, 16.503796, 1...  Northern Cardinal
#
# [5422 rows x 2 columns]

# %%
X = np.array(features_and_labels_df['features'].tolist())
Y = np.array(features_and_labels_df['labels'].tolist())

# %%
print(X.shape)
print(Y.shape)
# Out:
# (5422, 39)
# (5422,)

# %%
y = np.array(pd.get_dummies(Y))
y = y.astype(int)

# %%
def get_species_name(output_array, main_array=y):
    for i in range(len(main_array)):
        if np.array_equal(main_array[i], output_array):
            return Y[i]
    return None

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
model = Sequential([
    Dense(512, activation='relu', input_shape=(X.shape[1],)),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dropout(0.5),
    Dense(y.shape[1], activation='softmax')
])

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 512)               20480
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_12 (Dense)            (None, 256)               131328
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_14 (Dense)            (None, 64)                8256
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_15 (Dense)            (None, 32)                2080
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_16 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 195,205
# Trainable params: 195,205
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 136/136 [==============================] - 1s 4ms/step - loss: 1.0035 - accuracy: 0.5246 - val_loss: 1.0124 - val_accuracy: 0.4986
# Epoch 2/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9956 - accuracy: 0.5359 - val_loss: 1.0095 - val_accuracy: 0.4922
# Epoch 3/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9838 - accuracy: 0.5340 - val_loss: 1.0363 - val_accuracy: 0.4876
# Epoch 4/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9633 - accuracy: 0.5439 - val_loss: 0.9771 - val_accuracy: 0.5060
# Epoch 5/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9893 - accuracy: 0.5444 - val_loss: 0.9564 - val_accuracy: 0.5161
# Epoch 6/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9477 - accuracy: 0.5469 - val_loss: 0.9316 - val_accuracy: 0.5641
# Epoch 7/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9413 - accuracy: 0.5425 - val_loss: 0.9397 - val_accuracy: 0.5410
# Epoch 8/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9761 - accuracy: 0.5432 - val_loss: 0.9611 - val_accuracy: 0.5189
# Epoch 9/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9603 - accuracy: 0.5384 - val_loss: 0.9684 - val_accuracy: 0.5456
# Epoch 10/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9475 - accuracy: 0.5499 - val_loss: 0.9351 - val_accuracy: 0.5558
# Epoch 11/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9229 - accuracy: 0.5612 - val_loss: 0.8832 - val_accuracy: 0.5641
# Epoch 12/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9182 - accuracy: 0.5721 - val_loss: 0.9280 - val_accuracy: 0.5622
# Epoch 13/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9153 - accuracy: 0.5718 - val_loss: 0.9451 - val_accuracy: 0.5521
# Epoch 14/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9362 - accuracy: 0.5571 - val_loss: 0.9200 - val_accuracy: 0.5512
# Epoch 15/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8932 - accuracy: 0.5857 - val_loss: 0.9362 - val_accuracy: 0.5714
# Epoch 16/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9064 - accuracy: 0.5697 - val_loss: 0.9466 - val_accuracy: 0.5364
# Epoch 17/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9111 - accuracy: 0.5808 - val_loss: 0.9197 - val_accuracy: 0.5668
# Epoch 18/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.9173 - accuracy: 0.5838 - val_loss: 0.8720 - val_accuracy: 0.5825
# Epoch 19/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8927 - accuracy: 0.5840 - val_loss: 0.9524 - val_accuracy: 0.5585
# Epoch 20/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8797 - accuracy: 0.6018 - val_loss: 0.8720 - val_accuracy: 0.6046
# Epoch 21/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8878 - accuracy: 0.5944 - val_loss: 0.9003 - val_accuracy: 0.6267
# Epoch 22/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8851 - accuracy: 0.5979 - val_loss: 0.8724 - val_accuracy: 0.6129
# Epoch 23/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8556 - accuracy: 0.6131 - val_loss: 0.8248 - val_accuracy: 0.6535
# Epoch 24/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8638 - accuracy: 0.6115 - val_loss: 0.8577 - val_accuracy: 0.6359
# Epoch 25/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8318 - accuracy: 0.6159 - val_loss: 0.8229 - val_accuracy: 0.6571
# Epoch 26/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8365 - accuracy: 0.6212 - val_loss: 0.7980 - val_accuracy: 0.6774
# Epoch 27/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8671 - accuracy: 0.6184 - val_loss: 0.8046 - val_accuracy: 0.6590
# Epoch 28/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8579 - accuracy: 0.6219 - val_loss: 0.8339 - val_accuracy: 0.6719
# Epoch 29/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8429 - accuracy: 0.6387 - val_loss: 0.8036 - val_accuracy: 0.6903
# Epoch 30/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8367 - accuracy: 0.6341 - val_loss: 0.7942 - val_accuracy: 0.6774
# Epoch 31/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8117 - accuracy: 0.6440 - val_loss: 0.7571 - val_accuracy: 0.6857
# Epoch 32/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7831 - accuracy: 0.6560 - val_loss: 0.7738 - val_accuracy: 0.7005
# Epoch 33/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7983 - accuracy: 0.6599 - val_loss: 0.7836 - val_accuracy: 0.6737
# Epoch 34/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8211 - accuracy: 0.6362 - val_loss: 0.8015 - val_accuracy: 0.6977
# Epoch 35/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7977 - accuracy: 0.6592 - val_loss: 0.7322 - val_accuracy: 0.7023
# Epoch 36/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8180 - accuracy: 0.6447 - val_loss: 0.7650 - val_accuracy: 0.6968
# Epoch 37/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.8125 - accuracy: 0.6624 - val_loss: 0.7567 - val_accuracy: 0.6820
# Epoch 38/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7939 - accuracy: 0.6647 - val_loss: 0.7593 - val_accuracy: 0.6885
# Epoch 39/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7679 - accuracy: 0.6737 - val_loss: 0.7481 - val_accuracy: 0.7023
# Epoch 40/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7835 - accuracy: 0.6717 - val_loss: 0.7341 - val_accuracy: 0.7023
# Epoch 41/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7642 - accuracy: 0.6770 - val_loss: 0.7663 - val_accuracy: 0.6820
# Epoch 42/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7494 - accuracy: 0.6885 - val_loss: 0.7558 - val_accuracy: 0.6885
# Epoch 43/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7911 - accuracy: 0.6779 - val_loss: 0.6799 - val_accuracy: 0.7392
# Epoch 44/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7574 - accuracy: 0.6864 - val_loss: 0.7193 - val_accuracy: 0.7180
# Epoch 45/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7560 - accuracy: 0.6929 - val_loss: 0.6732 - val_accuracy: 0.7300
# Epoch 46/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7320 - accuracy: 0.6993 - val_loss: 0.6718 - val_accuracy: 0.7069
# Epoch 47/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7519 - accuracy: 0.6862 - val_loss: 0.6804 - val_accuracy: 0.7364
# Epoch 48/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7322 - accuracy: 0.6970 - val_loss: 0.6789 - val_accuracy: 0.7290
# Epoch 49/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7271 - accuracy: 0.7079 - val_loss: 0.7049 - val_accuracy: 0.7198
# Epoch 50/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7135 - accuracy: 0.7129 - val_loss: 0.7072 - val_accuracy: 0.7032
# Epoch 51/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7263 - accuracy: 0.7035 - val_loss: 0.6656 - val_accuracy: 0.7309
# Epoch 52/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7238 - accuracy: 0.7033 - val_loss: 0.6934 - val_accuracy: 0.7152
# Epoch 53/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7360 - accuracy: 0.7051 - val_loss: 0.6606 - val_accuracy: 0.7198
# Epoch 54/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7122 - accuracy: 0.7132 - val_loss: 0.6427 - val_accuracy: 0.7512
# Epoch 55/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6858 - accuracy: 0.7139 - val_loss: 0.6442 - val_accuracy: 0.7318
# Epoch 56/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7303 - accuracy: 0.7028 - val_loss: 0.6160 - val_accuracy: 0.7447
# Epoch 57/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7029 - accuracy: 0.7125 - val_loss: 0.6326 - val_accuracy: 0.7355
# Epoch 58/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6701 - accuracy: 0.7226 - val_loss: 0.6275 - val_accuracy: 0.7355
# Epoch 59/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.7159 - accuracy: 0.7194 - val_loss: 0.6678 - val_accuracy: 0.7272
# Epoch 60/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.7256 - val_loss: 0.6192 - val_accuracy: 0.7392
# Epoch 61/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6883 - accuracy: 0.7293 - val_loss: 0.6415 - val_accuracy: 0.7253
# Epoch 62/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6858 - accuracy: 0.7291 - val_loss: 0.5955 - val_accuracy: 0.7696
# Epoch 63/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6506 - accuracy: 0.7468 - val_loss: 0.6298 - val_accuracy: 0.7493
# Epoch 64/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6788 - accuracy: 0.7424 - val_loss: 0.6327 - val_accuracy: 0.7382
# Epoch 65/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6499 - accuracy: 0.7563 - val_loss: 0.5948 - val_accuracy: 0.7622
# Epoch 66/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.7602 - val_loss: 0.5691 - val_accuracy: 0.7825
# Epoch 67/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6802 - accuracy: 0.7482 - val_loss: 0.5763 - val_accuracy: 0.7825
# Epoch 68/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6433 - accuracy: 0.7466 - val_loss: 0.5827 - val_accuracy: 0.7687
# Epoch 69/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6283 - accuracy: 0.7519 - val_loss: 0.5780 - val_accuracy: 0.7696
# Epoch 70/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6476 - accuracy: 0.7632 - val_loss: 0.5877 - val_accuracy: 0.7742
# Epoch 71/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.7537 - val_loss: 0.5590 - val_accuracy: 0.7862
# Epoch 72/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6183 - accuracy: 0.7639 - val_loss: 0.5548 - val_accuracy: 0.7871
# Epoch 73/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5975 - accuracy: 0.7773 - val_loss: 0.5480 - val_accuracy: 0.7797
# Epoch 74/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6574 - accuracy: 0.7521 - val_loss: 0.5333 - val_accuracy: 0.7825
# Epoch 75/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6401 - accuracy: 0.7620 - val_loss: 0.5869 - val_accuracy: 0.7724
# Epoch 76/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6300 - accuracy: 0.7727 - val_loss: 0.5369 - val_accuracy: 0.7899
# Epoch 77/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6271 - accuracy: 0.7648 - val_loss: 0.5766 - val_accuracy: 0.7705
# Epoch 78/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6077 - accuracy: 0.7747 - val_loss: 0.5535 - val_accuracy: 0.7797
# Epoch 79/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6173 - accuracy: 0.7650 - val_loss: 0.5533 - val_accuracy: 0.7908
# Epoch 80/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5810 - accuracy: 0.7846 - val_loss: 0.5555 - val_accuracy: 0.7760
# Epoch 81/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.7805 - val_loss: 0.5637 - val_accuracy: 0.7733
# Epoch 82/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6101 - accuracy: 0.7796 - val_loss: 0.5603 - val_accuracy: 0.7816
# Epoch 83/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5922 - accuracy: 0.7789 - val_loss: 0.5313 - val_accuracy: 0.8083
# Epoch 84/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5863 - accuracy: 0.7858 - val_loss: 0.5293 - val_accuracy: 0.8111
# Epoch 85/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6332 - accuracy: 0.7634 - val_loss: 0.5504 - val_accuracy: 0.7935
# Epoch 86/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6123 - accuracy: 0.7699 - val_loss: 0.5128 - val_accuracy: 0.8111
# Epoch 87/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5964 - accuracy: 0.7812 - val_loss: 0.4922 - val_accuracy: 0.8249
# Epoch 88/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.6007 - accuracy: 0.7791 - val_loss: 0.5180 - val_accuracy: 0.8083
# Epoch 89/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5650 - accuracy: 0.7902 - val_loss: 0.4824 - val_accuracy: 0.8157
# Epoch 90/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5665 - accuracy: 0.7782 - val_loss: 0.4676 - val_accuracy: 0.8240
# Epoch 91/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5503 - accuracy: 0.7969 - val_loss: 0.4762 - val_accuracy: 0.8258
# Epoch 92/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5463 - accuracy: 0.8012 - val_loss: 0.4838 - val_accuracy: 0.8304
# Epoch 93/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5375 - accuracy: 0.8098 - val_loss: 0.4553 - val_accuracy: 0.8369
# Epoch 94/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5704 - accuracy: 0.7927 - val_loss: 0.4662 - val_accuracy: 0.8516
# Epoch 95/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5618 - accuracy: 0.8031 - val_loss: 0.4761 - val_accuracy: 0.8175
# Epoch 96/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5619 - accuracy: 0.7962 - val_loss: 0.4670 - val_accuracy: 0.8221
# Epoch 97/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5701 - accuracy: 0.7853 - val_loss: 0.4748 - val_accuracy: 0.8240
# Epoch 98/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5368 - accuracy: 0.8089 - val_loss: 0.4537 - val_accuracy: 0.8286
# Epoch 99/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5680 - accuracy: 0.7925 - val_loss: 0.4737 - val_accuracy: 0.8203
# Epoch 100/100
# 136/136 [==============================] - 0s 3ms/step - loss: 0.5533 - accuracy: 0.8079 - val_loss: 0.4898 - val_accuracy: 0.8221

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 34/34 [==============================] - 0s 1ms/step - loss: 0.4898 - accuracy: 0.8221
# Test Loss: 0.48981499671936035
# Test Accuracy: 0.8221198320388794
